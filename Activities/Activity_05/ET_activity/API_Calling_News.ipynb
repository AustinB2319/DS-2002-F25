# %% [markdown]
# # Data Acquisition via API Calls (NewsAPI)

# %% [markdown]
# ---

# %% [markdown]
# ## Phase 1: Setup and Security

# %% [markdown]
# ### Install Dependencies

# %%
# Install the necessary library for loading environment variables (like API keys)
# !pip install python-dotenv

print("Dependencies installed successfully.")
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.1.1
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Dependencies installed successfully.

# %% [markdown]
# ### Import Modules
# Import all necessary Python libraries. Note that `requests` is the primary tool for submitting HTTP requests.

# %%
import numpy as np
import pandas as pd
import os
import requests
import json
import dotenv
from datetime import datetime

print("Modules imported.")
# Out:
# Modules imported.

# %% [markdown]
# ### Load Environment Variables
# This loads your `.env` file, which is crucial for securely handling your NewsAPI key without exposing it in the notebook.

# %%
# Load the .env file to access environment variables (e.g., your API Key)
dotenv.load_dotenv()

print("Environment variables loaded.")
# Out:
# Environment variables loaded.

# %% [markdown]
# ### Retrieve API Key
# We access the stored API key using os.getenv().

# %%
# Get the News API key from the environment variables
newskey = os.getenv('newskey')

# We won't print the key, but we confirm it's loaded (e.g., by checking its length)
if newskey:
    print("News API key successfully retrieved.")
else:
    print("ERROR: News API key not found. Check your .env file.")
# Out:
# News API key successfully retrieved.

# %% [markdown]
# ---

# %% [markdown]
# ## Phase 2: Building the API Request Components
# An HTTP request requires four main components: URL root, endpoint, headers (for security/metadata), and parameters (the query).

# %% [markdown]
# ### Build User Agent Header
# Many APIs require a User-agent to identify the client application. We use httpbin.org to dynamically grab a standard User-agent string.

# %%
# 1. Get a standard User-agent string
r = requests.get('https://httpbin.org/user-agent')
useragent = json.loads(r.text)['user-agent']

# 2. Build the full headers dictionary
# The API key is sent via the 'X-Api-Key' header, a common secure method.
headers = {'User-agent': useragent,
           'X-Api-Key': newskey}

print(f"User-agent: {useragent}")
print("Headers dictionary created, containing the API key.")
# Out:
# User-agent: python-requests/2.32.4
# Headers dictionary created, containing the API key.

# %% [markdown]
# ### Define URL Root and Endpoint
# This defines the fixed address for the NewsAPI service we want to use.

# %%
# Define the fixed URL parts
root = 'https://newsapi.org'
endpoint = '/v2/everything' # This endpoint searches all articles

print(f"API Base URL: {root + endpoint}")
# Out:
# API Base URL: https://newsapi.org/v2/everything

# %% [markdown]
# ### Define Query Parameters
# Parameters are used to customize the search (e.g., topic, language, date).

# %%
# Define the search parameters as a Python dictionary
params = {'q': '"tallest mountain"',  # Topic to search for (using quotes for exact phrase)
         'searchIn': 'content',      # Search within the article content
         'language': 'en',           # Restrict to English articles
         'pageSize': 100}            # Request up to 100 articles

print("Query parameters defined:")
print(params)
# Out:
# Query parameters defined:
# {'q': '"tallest mountain"', 'searchIn': 'content', 'language': 'en', 'pageSize': 100}

# %% [markdown]
# ---

# %% [markdown]
# ## Phase 3: API Execution and Parsing

# %% [markdown]
# ### Submit the GET Request
# This cell sends the request and checks the response status. A `<Response [200]>` indicates success.

# %%
# Combine the components and submit the GET request
r = requests.get(root + endpoint,
                headers = headers,
                params = params)

# Display the response object (it should show <Response [200]>)
print(f"Request submitted. Status: {r}")
# Out:
# Request submitted. Status: <Response [200]>

# %% [markdown]
# ### Parse the JSON Response
# The response (`r.text`) is a single string containing the JSON data. We use `json.loads()` to convert this string into a usable Python dictionary.

# %%
# Convert the JSON response string into a Python dictionary
myjson = json.loads(r.text)

print(f"JSON response converted to a Python dictionary (Type: {type(myjson)})")
print("Top-level keys in the response:")
print(list(myjson.keys()))
# Out:
# JSON response converted to a Python dictionary (Type: <class 'dict'>)
# Top-level keys in the response:
# ['status', 'totalResults', 'articles']

# %% [markdown]
# ### View Raw JSON Data Structure (Optional)
# This cell is often left commented out to avoid printing a massive wall of text but serves as a way to inspect the data structure.

# %%
# Uncomment this line to inspect the full structure of the JSON dictionary
# print(json.dumps(myjson, indent=4))

# %% [markdown]
# ### Normalize JSON to DataFrame
# The key data is nested under the articles key. Pandas’ json_normalize() function flattens this nested data into a clean, tabular DataFrame.

# %%
# Use json_normalize to extract the list of article dictionaries ('articles')
news_df = pd.json_normalize(myjson, record_path = ['articles'])

print(f"DataFrame created with {len(news_df)} articles.")
print("First 5 rows of the DataFrame:")
display(news_df.head())
# Out:
# DataFrame created with 21 articles.
# First 5 rows of the DataFrame:
#                                               author  \
# 0                                       Lydia Mansel
# 1                                   Express Web Desk
# 2                                    Georgie English
# 3                                           ABC News
# 4  sascha.pare@futurenet.com (Sascha Pare) , Sasc...
#
#                                                title  \
# 0  This Historic Train Climbs the Tallest Mountai...
# 1  Polish skier becomes first to climb, ski down ...
# 2             CLEAREST EVER SIGNS OF LIFE ON MARS...
# 3  Sudan landslide claims 1,000 lives, village 'c...
# 4  The geology that holds up the Himalayas is not...
#
#                                          description  \
# 0  Riding the Mount Washington Cog Railway is one...
# 1  In 2018, the Polish climber was the first pers...
# 2  NASA has revealed the clearest signs of life o...
# 3  The Sudan Liberation Movement/Army is appealin...
# 4  A 100-year-old theory explaining how Asia can ...
#
#                                                  url  \
# 0  https://www.travelandleisure.com/mount-washing...
# 1  https://indianexpress.com/article/world/polish...
# 2  https://www.the-sun.com/tech/15159152/nasa-mar...
# 3  https://www.abc.net.au/news/2025-09-02/sudan-l...
# 4  https://www.livescience.com/planet-earth/geolo...
#
#                                           urlToImage           publishedAt  \
# 0  https://s.yimg.com/ny/api/res/1.2/JmSXRiaGiWkv...  2025-09-20T16:00:00Z
# 1  https://images.indianexpress.com/2025/09/polan...  2025-09-28T04:50:59Z
# 2  https://www.the-sun.com/wp-content/uploads/sit...  2025-09-10T17:34:37Z
# 3  https://live-production.wcms.abc-cdn.net.au/73...  2025-09-02T07:52:51Z
# 4  https://cdn.mos.cms.futurecdn.net/KMwyEqed8eMT...  2025-08-30T15:50:00Z
#
#                                              content    source.id  \
# 0  Key Points\r\n<ul><li>The Mount Washington Cog...         None
# 1  Polish skier Andrzej Bargiel made history this...         None
# 2  NASA has revealed the clearest signs of life o...         None
# 3  At least 1,000 people were killed in a landsli...  abc-news-au
# 4  Scientists may have just toppled a 100-year-ol...         None
#
#           source.name
# 0      Travel+Leisure
# 1  The Indian Express
# 2         The-sun.com
# 3       ABC News (AU)
# 4        Live Science

# %% [markdown]
# ---

# %% [markdown]
# ## Phase 4: Data Analysis and Export

# %% [markdown]
# ### Clean and Prepare for Export
# Perform a final step to ensure the data is properly formatted before saving.

# %%
# Clean up the publishedAt column (convert to datetime)
news_df['publishedAt'] = pd.to_datetime(news_df['publishedAt'])

# Select a final set of columns for the CSV
final_df = news_df[['publishedAt', 'title', 'description', 'url', 'source.name', 'author']].copy()

print("DataFrame prepared for export.")
# Out:
# DataFrame prepared for export.

# %% [markdown]
# ### Export to CSV
# This is the final Load (L) phase of the data acquisition process.

# %%
# Define a filename based on the current date for organization
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
output_filename = f'news_articles_{timestamp}.csv'

# Export the final clean DataFrame to a CSV file
final_df.to_csv(output_filename, index=False)

print(f"Successfully exported {len(final_df)} articles to {output_filename}")
# Out:
# Successfully exported 21 articles to news_articles_20250930_011614.csv

# %% [markdown]
# ---

# %% [markdown]
# ## Function Definition (Optional Consolidation)
# This final cell provides the consolidation of all steps into a single, reusable function—demonstrating how a script would execute the entire API call process.

# %%
def grab_latest_articles():
    """
    Consolidates all steps: builds request, calls API, parses JSON, and returns a DataFrame.
    """
    
    # Prompt the user
    topic = input("Please enter your topic of interest: ")
    
    # Build our Headers
    newskey = os.getenv('newskey')
    r = requests.get('https://httpbin.org/user-agent')
    useragent = json.loads(r.text)['user-agent']
    headers = {'User-agent': useragent,
               'X-Api-Key': newskey}

    # Build our URL and Parameters
    root = 'https://newsapi.org'
    endpoint = '/v2/everything'
    params = {'q': topic,
              'searchIn': 'content',
              'language': 'en',
              'pageSize': 100}
    
    # Submit our Request
    r = requests.get(root + endpoint,
                headers = headers,
                params = params)
    
    # Create and return the pandas dataframe
    myjson = json.loads(r.text)
    news_df = pd.json_normalize(myjson, record_path = ['articles'])
    
    return news_df

# %%
grab_latest_articles()
# Out:
#                                                author  \
# 0                                      Ellyn Lapointe
# 1                                        Kat Lonsdorf
# 2                                        Maria Popova
# 3   sascha.pare@futurenet.com (Sascha Pare) , Sasc...
# 4                                           Itai Gilo
# 5                                      Michael Crider
# 6                                              Dmitry
# 7                              Aberystwyth University
# 8                                       Mathew Duggan
# 9                                               Tom G
# 10                                       Sachin Rawat
# 11               Editor@juxtapoz.com (Editor -- Evan)
# 12                                           AFP News
# 13                                    Jessica Stewart
# 14                                           ABC News
# 15                                         Matt Simon
# 16                                         Tom Clarke
# 17                                        Sean Cudahy
# 18                                    Marric Stephens
# 19                                 whyevolutionistrue
# 20                                                AFP
# 21                                   Associated Press
# 22  ben.turner@futurenet.com (Ben Turner) , Ben Tu...
# 23                                   Associated Press
# 24                                   Michael Drummond
# 25                                           RTÉ News
# 26                                                AFP
# 27                                               None
# 28                                     Ariana Harwicz
# 29                                      Corin Cesaric
# 30                                      Trending Desk
# 31                                          Neil Shea
# 32                          Arden Dier with Newser.AI
# 33                                    Natalie Preddie
# 34                                     Arun Shanmugam
# 35                                               None
# 36                                               None
# 37                        Universalis/Jerusalem Bible
# 38                                        Ben Gilbert
# 39           Gary Abernathy, The Empowerment Alliance
# 40             Amy Deen Westbrook, David A. Westbrook
# 41                                      Dave Vellante
# 42                                               None
#
#                                                 title  \
# 0    The World’s Biggest Iceberg Is Finally Crumbling
# 1   The world's oldest and largest iceberg will so...
# 2   The Heart of the Andes and the Invention of Vi...
# 3   40-year-old 'queen of icebergs' A23a is no lon...
# 4             How We Built Our lakeFS Iceberg Catalog
# 5   Steam update lets you rename your games for ea...
# 6   Spectacular Winning Photos from the 2025 Analo...
# 7   Andes glaciers grew during Younger Dryas perio...
# 8                  Greenland Is a Beautiful Nightmare
# 9   12 Years Of Travel, Yet Nothing Could Prepare ...
# 10                  Recreating Iceberg Flips in a Lab
# 11  The Waves: David Benjamin Sherry @ Huxley-Parl...
# 12  Once King Of The Seas, A Giant Iceberg Is Fina...
# 13  Capturing the Eternal Beauty of Greenland‘s Ev...
# 14  Scientists sound death knell for 'doomed' gian...
# 15  A fiber optic cable spied on Greenland’s glaci...
# 16  One of the world's biggest icebergs breaking u...
# 17  Traveling to Greenland on United Airlines: Wha...
# 18              Predicting Sea Waves More Effectively
# 19       To the Arctic, part 4. Walruses and icebergs
# 20  Colossal Antarctic Iceberg Is Finally Breaking...
# 21  Retreating Alsek Glacier reveals new island in...
# 22  Science news this week: A key Atlantic current...
# 23  Most enduring and biggest iceberg breaks apart...
# 24  British 'Thor' becomes first person to swim 1,...
# 25  World's biggest iceberg could disappear 'in co...
# 26  Once king of the seas, a giant iceberg is fina...
# 27  How to see the blood moon total lunar eclipse ...
# 28                                              Unfit
# 29  Stop Pouring Grease Down Your Drain. Your Wall...
# 30  World’s largest iceberg A23A breaks apart in A...
# 31                                   Tales Teeth Tell
# 32   Title of World's Largest Iceberg Has Transferred
# 33  A traveler's guide to the coastlines, culture,...
# 34  Unlock the power of Apache Iceberg v3 deletion...
# 35  Fermeuse Energy floats plan for Fermeuse LNG t...
# 36  What you need to know about AI and climate change
# 37  Catholic Caucus: Daily Mass Readings 30-August...
# 38  Sword Of The Sea is a technicolor trip of a ga...
# 39  ‘Morale is destroyed’: ‘Renewables’ movement h...
# 40                              Sisyphus the Director
# 41  Dave Vellante’s Breaking Analysis: The complet...
# 42  Long before Kimmel controversy, late-night hos...
#
#                                           description  \
# 0   Experts believe the "megaberg" known as A23a c...
# 1   The iceberg, known as A23a, has been on a jour...
# 2   In the spring of 1859, as On the Origin of Spe...
# 3   A giant iceberg called A23a that broke off Ant...
# 4   A behind-the-scenes look at the design decisio...
# 5   For a huge portion of PC gamers, Steam might a...
# 6   Discovery of the Year: “Everyone Is Icarus” by...
# 7   Andean glaciers advanced during an acute perio...
# 8   Greenland is a complicated topic here in Denma...
# 9   This summer adventure was truly one of a kind,...
# 10  Author(s): Sachin RawatExperiments with small,...
# 11  Huxley-Parlour are delighted to present The Wa...
# 12  Nearly 40 years after breaking off Antarctica,...
# 13  Capturing the Eternal Beauty of Greenland‘s Ev...
# 14  A colossal iceberg ranked among the oldest and...
# 15  One of the buzziest technologies in modern sci...
# 16  The rapid break-up of the iceberg could repres...
# 17  United Airlines announced it will fly directly...
# 18  Author(s): Marric StephensResearchers have dev...
# 19  This post occupies one day of our trip, again ...
# 20  Nearly 40 years after breaking off Antarctica,...
# 21  While many glaciers in Alaska are retreating, ...
# 22  Sept. 6, 2025: Our weekly roundup of the lates...
# 23  The world's largest iceberg, A23A, may not las...
# 24  British extreme athlete Ross Edgley has become...
# 25  Nearly 40 years after breaking off Antarctica,...
# 26  Nearly 40 years after breaking off Antarctica,...
# 27  The last total lunar eclipse visible in the UK...
# 28  I don’t care about anything else, I have them,...
# 29  For the sake of your pipes and budget, never d...
# 30  The colossal iceberg A23A, once the world's la...
# 31  My tooth aches. I feel it with each plodding s...
# 32  After nearly four decades, one of the world's ...
# 33  From digging for dinosaur bones in Alberta's b...
# 34  As modern data architectures expand, Apache Ic...
# 35  A large natural gas revserve in the Jeanne d'A...
# 36  This is a re-post from Yale Climate Connection...
# 37  31 August 2025 22nd Sunday in Ordinary TimeLin...
# 38  Mind-bending mechanics and cosmic backdrops de...
# 39  'Alternative' energy calls itself only path fo...
# 40  Sidney Weinberg and his son John Weinberg both...
# 41  Breaking Analysis is a weekly editorial progra...
# 42  Late night hosts condemned the brief suspensio...
#
#                                                   url  \
# 0   https://gizmodo.com/the-worlds-biggest-iceberg...
# 1   https://www.npr.org/2025/09/05/nx-s1-5527058/l...
# 2   https://www.themarginalian.org/2025/09/16/fred...
# 3   https://www.livescience.com/planet-earth/antar...
# 4   https://lakefs.io/blog/how-we-built-lakefs-ice...
# 5   https://www.pcworld.com/article/2905369/steam-...
# 6   https://designyoutrust.com/2025/09/spectacular...
# 7   https://phys.org/news/2025-09-andes-glaciers-g...
# 8   https://matduggan.com/greenland-is-a-beautiful...
# 9   https://www.boredpanda.com/summer-in-the-arcti...
# 10           https://physics.aps.org/articles/v18/159
# 11  https://www.juxtapoz.com/news/photography/the-...
# 12  https://www.ibtimes.com/once-king-seas-giant-i...
# 13  https://mymodernmet.com/albert-dros-greenland-...
# 14  https://www.abc.net.au/news/2025-09-05/a23a-ic...
# 15  https://grist.org/climate/a-fiber-optic-cable-...
# 16  https://news.sky.com/story/one-of-the-worlds-b...
# 17  https://thepointsguy.com/travel/visiting-green...
# 18          https://physics.aps.org/articles/v18/s114
# 19  https://whyevolutionistrue.com/2025/08/30/to-t...
# 20  https://www.sciencealert.com/colossal-antarcti...
# 21  https://www.bostonherald.com/2025/09/18/retrea...
# 22  https://www.livescience.com/health/surgery/sci...
# 23  https://www.bostonherald.com/2025/09/04/climat...
# 24  https://news.sky.com/story/ross-edgley-british...
# 25  https://www.rte.ie/news/newslens/2025/0902/153...
# 26  https://www.digitaljournal.com/world/once-king...
# 27  https://news.sky.com/story/how-to-see-the-bloo...
# 28  https://www.nplusonemag.com/issue-51/fiction-d...
# 29  https://www.cnet.com/home/kitchen-and-househol...
# 30  https://economictimes.indiatimes.com/news/new-...
# 31  https://www.lastwordonnothing.com/2025/09/19/t...
# 32  https://www.newser.com/story/374574/title-of-w...
# 33  https://www.nationalgeographic.com/travel/arti...
# 34  https://aws.amazon.com/blogs/big-data/unlock-t...
# 35  https://www.cbc.ca/news/canada/newfoundland-la...
# 36  https://skepticalscience.com/ai-and-climate-ch...
# 37  https://freerepublic.com/focus/f-religion/4337...
# 38  https://www.techradar.com/gaming/sword-of-the-...
# 39  https://www.wnd.com/2025/09/renewables-movemen...
# 40  https://clsbluesky.law.columbia.edu/2025/09/10...
# 41  https://siliconangle.com/2025/08/29/dave-vella...
# 42  https://www.foxnews.com/media/long-before-kimm...
#
#                                            urlToImage           publishedAt  \
# 0   https://gizmodo.com/app/uploads/2025/09/iceber...  2025-09-03T15:20:39Z
# 1   https://npr.brightspotcdn.com/dims3/default/st...  2025-09-05T09:01:00Z
# 2   https://www.themarginalian.org/wp-content/uplo...  2025-09-16T18:08:02Z
# 3   https://cdn.mos.cms.futurecdn.net/qsUvtYCWh5N7...  2025-09-04T15:19:01Z
# 4   https://lakefs.io/wp-content/uploads/2025/08/1...  2025-09-07T06:43:42Z
# 5   https://www.pcworld.com/wp-content/uploads/202...  2025-09-10T15:43:10Z
# 6   https://designyoutrust.com/wp-content/uploads/...  2025-09-28T12:56:19Z
# 7   https://scx2.b-cdn.net/gfx/news/hires/2025/stu...  2025-09-23T13:31:03Z
# 8   https://matduggan.com/content/images/2024/01/f...  2025-09-27T15:46:46Z
# 9   https://www.boredpanda.com/blog/wp-content/upl...  2025-09-04T14:27:49Z
# 10  https://physics.aps.org/assets/aecda656-7e74-4...  2025-09-12T10:00:00Z
# 11  https://www.juxtapoz.com/media/k2/items/cache/...  2025-09-19T07:35:56Z
# 12  https://d.ibtimes.com/en/full/4619227/infograp...  2025-09-02T16:36:17Z
# 13  https://mymodernmet.com/wp/wp-content/uploads/...  2025-09-04T16:35:53Z
# 14  https://live-production.wcms.abc-cdn.net.au/ac...  2025-09-05T03:30:15Z
# 15  https://grist.org/wp-content/uploads/2025/09/I...  2025-09-05T08:15:00Z
# 16  https://e3.365dm.com/25/09/1600x900/skynews-ic...  2025-09-03T14:16:00Z
# 17  https://runway-media-production.global.ssl.fas...  2025-09-17T13:30:07Z
# 18  https://physics.aps.org/assets/08de203a-56b5-4...  2025-09-18T10:00:00Z
# 19  https://whyevolutionistrue.com/wp-content/uplo...  2025-08-30T14:00:04Z
# 20  https://www.sciencealert.com/images/2025/01/Ic...  2025-09-03T13:00:59Z
# 21  https://www.bostonherald.com/wp-content/upload...  2025-09-18T23:28:52Z
# 22  https://cdn.mos.cms.futurecdn.net/Vz4jczmkSSg9...  2025-09-06T04:00:00Z
# 23  https://www.bostonherald.com/wp-content/upload...  2025-09-04T23:49:54Z
# 24  https://e3.365dm.com/25/07/1600x900/skynews-ro...  2025-09-08T09:31:00Z
# 25        https://www.rte.ie/images/0021cb50-1600.jpg  2025-09-02T17:05:52Z
# 26  https://www.digitaljournal.com/wp-content/uplo...  2025-09-02T16:37:20Z
# 27  https://e3.365dm.com/25/03/1600x900/skynews-bl...  2025-09-05T07:37:00Z
# 28  https://www.nplusonemag.com/wp-content/uploads...  2025-09-10T14:56:36Z
# 29  https://www.cnet.com/a/img/resize/c5ad70612363...  2025-09-07T12:00:00Z
# 30  https://img.etimg.com/thumb/msid-123717127,wid...  2025-09-05T09:17:50Z
# 31                                               None  2025-09-19T08:00:00Z
# 32  https://img1-azrcdn.newser.com/image/1631814-1...  2025-09-03T16:00:00Z
# 33  https://i.natgeofe.com/n/9880fff6-af55-4a5f-ae...  2025-09-02T00:00:00Z
# 34  https://d2908q01vomqb2.cloudfront.net/b6692ea5...  2025-09-17T19:26:40Z
# 35  https://i.cbc.ca/1.7596956.1753832223!/cantoIm...  2025-09-07T08:30:00Z
# 36  https://skepticalscience.com/public/assets/ima...  2025-09-15T04:54:07Z
# 37                                               None  2025-08-31T17:21:05Z
# 38  https://cdn.mos.cms.futurecdn.net/4QxtHbNhCZvh...  2025-09-06T12:00:00Z
# 39  https://www.wnd.com/wp-content/uploads/2024/06...  2025-09-20T20:52:20Z
# 40  https://s0.wp.com/_si/?t=eyJpbWciOiJodHRwczpcL...  2025-09-10T04:05:50Z
# 41  https://d15shllkswkct0.cloudfront.net/wp-conte...  2025-08-29T10:33:12Z
# 42  https://static.foxnews.com/foxnews.com/content...  2025-09-26T12:19:05Z
#
#                                               content            source.id  \
# 0   Just months ago, the worlds largest iceberg we...                 None
# 1   It's been a long and unusual journey for the w...                 None
# 2   In the spring of 1859, as On the Origin of Spe...                 None
# 3   An iceberg that was once the size of Rhode Isl...                 None
# 4   A behind-the-scenes look at the design decisio...                 None
# 5   Skip to contentWhen you purchase through links...                 None
# 6   Discovery of the Year: “Everyone Is Icarus” by...                 None
# 7   Andean glaciers advanced during an acute perio...                 None
# 8   Greenland is a complicated topic here in Denma...                 None
# 9   At 82° north, surrounded by endless ice and th...                 None
# 10  Tipping point. Icebergs—like this one off the ...                 None
# 11  Huxley-Parlour are delighted to present The Wa...                 None
# 12  Nearly 40 years after breaking off Antarctica,...                 None
# 13  Once again, Albert Dros has made us swoon with...                 None
# 14  A colossal iceberg ranked among the oldest and...          abc-news-au
# 15  One of the buzziest technologies in modern sci...                 None
# 16  It's the mother of all break-ups.\r\nThe life ...                 None
# 17  Next week, United Airlines will wind down its ...                 None
# 18  Landing an aircraft on a floating platform, tr...                 None
# 19  This post occupies one day of our trip, again ...                 None
# 20  Nearly 40 years after breaking off Antarctica,...                 None
# 21  By BECKY BOHRER\r\nJUNEAU, Alaska (AP) A retre...                 None
# 22  The watery part of the world dominated our sci...                 None
# 23  By SETH BORENSTEIN\r\nThe worlds largest and m...                 None
# 24  British extreme athlete Ross Edgley has become...                 None
# 25  Nearly 40 years after breaking off Antarctica,...                  rte
# 26  The world's largest iceberg is breaking up - C...                 None
# 27  If you look up to the sky on Sunday, you might...                 None
# 28  We dont decide anything over the course of a l...                 None
# 29  When we cook with oil, butter or fatty foods s...                 None
# 30  The worlds largest and longest-lasting iceberg...   the-times-of-india
# 31  My tooth aches. I feel it with each plodding s...                 None
# 32  After nearly four decades, one of the world's ...                 None
# 33  Canada's vast expanse offers families an unpar...  national-geographic
# 34  As modern data architectures expand, Apache Ic...                 None
# 35  Fermeuse Energy Limited is looking to put the ...             cbc-news
# 36  Posted on 15 September 2025 by Guest Author\r\...                 None
# 37  31 August 2025 22nd Sunday in Ordinary Time\r\...                 None
# 38  Why you can trust TechRadar\r\nWe spend hours ...            techradar
# 39  This article was originally published at The E...                 None
# 40  Sidney Weinberg and his son John Weinberg both...                 None
# 41  Breaking Analysis is a weekly editorial progra...                 None
# 42  The temporary suspension of "Jimmy Kimmel Live...             fox-news
#
#                      source.name
# 0                    Gizmodo.com
# 1                            NPR
# 2             Themarginalian.org
# 3                   Live Science
# 4                      Lakefs.io
# 5                        PCWorld
# 6             Designyoutrust.com
# 7                       Phys.Org
# 8                  Matduggan.com
# 9                 Boredpanda.com
# 10                       Aps.org
# 11                  Juxtapoz.com
# 12  International Business Times
# 13                 My Modern Met
# 14                 ABC News (AU)
# 15                         Grist
# 16                       Sky.com
# 17                The Points Guy
# 18                       Aps.org
# 19        Whyevolutionistrue.com
# 20                  ScienceAlert
# 21                 Boston Herald
# 22                  Live Science
# 23                 Boston Herald
# 24                       Sky.com
# 25                           RTE
# 26               Digital Journal
# 27                       Sky.com
# 28               Nplusonemag.com
# 29                          CNET
# 30            The Times of India
# 31         Lastwordonnothing.com
# 32                        Newser
# 33           National Geographic
# 34                    Amazon.com
# 35                      CBC News
# 36          Skepticalscience.com
# 37              Freerepublic.com
# 38                     TechRadar
# 39                       Wnd.com
# 40                  Columbia.edu
# 41             SiliconANGLE News
# 42                      Fox News
